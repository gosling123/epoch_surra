# %%
from epoch_scripts.hot_elec_calc import *

# %%
dir = 'Data_500_3/Data_12'

# %%
he = hot_electron(dir = dir)

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3)
he.get_flux_dist(ax = ax1, plot=True, log = True)
he.split_dist(n = 4, ax = ax2, plot=True, log = True)
he.get_hot_e_temp(n = 10, ax = ax3, plot = True)

plt.gcf().set_size_inches(30,10)

# %%
he.fit_maxwellians(n = 4, plot = True, log = True)

# %%
he.amplitudes
# Out:
# array([4.52690038e-17, 2.50634536e-17, 8.96321369e-18, 1.80093977e-18])
