# %%
from epoch_calculator import*
from visuliser import*
from utils import*
import numpy as np
import matplotlib.pyplot as plt

# %%
dir = 'Data'

# %% [markdown]
# ## Get Plasma and Laser parameters

# %%
epoch_data = Laser_Plasma_Params(dir = dir)

epoch_data.read_data()

epoch_data.get_spatio_temporal()

epoch_data.get_plasma_param()

# %% [markdown]
# ## Get Ouputted Fields and FFTs

# %%
epoch_fields = EM_fields(dir= dir)

Ex = epoch_fields.get_2D_Electric_Field_x()
Ey = epoch_fields.get_2D_Electric_Field_y()
Bz = epoch_fields.get_2D_Magnetic_Field_z()

Ex_2D_FFT = epoch_fields.get_2D_FFT(field = 'Ex', square_mod=True)

# %%
vis = epoch_plotter(dir = 'Data')

vis.density_plot()

# %%
vis.dispersion_2D_plot(data = Ex_2D_FFT, case = 'Ex')

# %%
vis.backscatter_flux_plot(reflectivity=False)
