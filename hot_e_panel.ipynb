# %%
from epoch_scripts.hot_elec_calc import *

# %%
dir = 'Data_2D_1/Data_1'
dir2 = 'Data_25'

# %%
he = hot_electron(dir = dir)
he2 = hot_electron(dir = dir2)

# %%
f, (ax1, ax2) = plt.subplots(1, 2)
he.get_flux_dist(ax = ax2, plot=True, log = True)
he2.get_flux_dist(ax = ax1, plot=True, log = True)

# %%
he.get_hot_e_temp(n = 10, ax = None, plot = True)

# %%
he.fit_maxwellians(n = 6, plot = True, log = True)
