# %%
from gp import *

# %%
input_file = '../training_results/1D_500/train_inputs.json'
var_file = '../training_results/1D_500/train_outputs_var.json'
output_file = '../training_results/1D_500/train_outputs_mean.json'
input_type = 'I'
output_type = 'P'

# %%
gp = LPI_GP_1D(input_file = input_file, input_type = input_type, output_file = output_file, output_type = output_type, var_file = var_file)

# %%
X = gp.get_input()
Y = gp.get_noise_var()

# %%
gp.optimise_noise_GP()
# Out:
# l =  0.023299518105153717 var =  0.04714866363457394

# %%
X_star = np.geomspace(1e14, 1e16, 1000)[:,None]


Y_star, sig_epi = gp.noise_GP_predict(X_star, get_std=True)

Y_star = 2*np.sqrt(Y_star)

# %%
Y_s = Y_star.flatten()
X_s = X_star.flatten()
error_epi = 2*np.sqrt(sig_epi)
plt.semilogx(X_s, Y_s)
plt.plot(X, 2*np.sqrt(Y), 'kx')
